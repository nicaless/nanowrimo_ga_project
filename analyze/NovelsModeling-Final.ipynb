# %%
import numpy as np
import pandas as pd

import warnings
from matplotlib.colors import ListedColormap

warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# Now that I've created a model to predict which writers will be winners based on their past NaNoWriMo performances, let's attempt to predict which novels will be winning novels based on what little we know about them: their genre, synopsis, and excerpt.

# %%
novel_features = pd.read_csv("../clean data/novel_features.csv", index_col = 0)
novel_features.head()
# Out:
#        Writer Name                                 Novel Name  \
# 0         Nicaless                   Novel: Lauren's Birthday
# 1         Nicaless  Novel: A Mystery in the Kingdom of Aermon
# 2  Rachel B. Moore                   Novel: Finding Fortunato
# 3  Rachel B. Moore                       Novel: The Residency
# 4  Rachel B. Moore              Novel: The Jew From Fortunato
#
#               Genre  Final Word Count Daily Average  Winner  \
# 0       Young Adult             24229           807       0
# 1           Fantasy             50919         1,697       1
# 2          Literary             50603         1,686       1
# 3          Literary             50425         1,680       1
# 4  Literary Fiction             41447         1,381       0
#
#                                             Synopses  \
# 0                                        \n<p></p>\n
# 1  \n<p>Hitoshi is appointed the youngest Judge a...
# 2  \n<p>Sam and Anna Gold and their newly adoptiv...
# 3  \n<p>It's every writer's dream - an all-expens...
# 4  \n<p>20-something Andre Levinsky is a fish out...
#
#                                                  url     Novel Date  \
# 0  http://nanowrimo.org/participants/nicaless/nov...  November 2015
# 1  http://nanowrimo.org/participants/nicaless/nov...  November 2014
# 2  http://nanowrimo.org/participants/rachel-b-moo...  November 2015
# 3  http://nanowrimo.org/participants/rachel-b-moo...  November 2014
# 4  http://nanowrimo.org/participants/rachel-b-moo...  November 2013
#
#                                              Excerpt        ...         \
# 0                                        \n<p></p>\n        ...
# 1  \n<p>This story, funnily enough, started out a...        ...
# 2                                        \n<p></p>\n        ...
# 3                                        \n<p></p>\n        ...
# 4                                        \n<p></p>\n        ...
#
#    num uniques  num sentences  paragraphs  fk score  has excerpt  \
# 0            0              0           0      0.00            0
# 1           42              3           1     65.73            1
# 2          109              7           4     58.62            0
# 3           51              4           3     65.73            0
# 4           93              4           1     56.93            0
#
#    num words excerpt  num uniques excerpt  num sentences excerpt  \
# 0                  0                    0                      0
# 1                132                   96                     13
# 2                  0                    0                      0
# 3                  0                    0                      0
# 4                  0                    0                      0
#
#    paragraphs excerpt  fk score excerpt
# 0                   0              0.00
# 1                   7             78.25
# 2                   0              0.00
# 3                   0              0.00
# 4                   0              0.00
#
# [5 rows x 24 columns]

# %%
del novel_features['Novel Name']
del novel_features['Genre']
del novel_features['Final Word Count']
del novel_features['Daily Average']
del novel_features['Synopses']
del novel_features['url']
del novel_features['Excerpt']
del novel_features['Writer Name']
novel_features.columns
# Out:
# Index([u'Winner', u'Novel Date', u'has genre', u'standard genre',
#        u'has_synopses', u'num words', u'num uniques', u'num sentences',
#        u'paragraphs', u'fk score', u'has excerpt', u'num words excerpt',
#        u'num uniques excerpt', u'num sentences excerpt', u'paragraphs excerpt',
#        u'fk score excerpt'],
#       dtype='object')

# %%
novel_features.head()
# Out:
#    Winner     Novel Date  has genre  standard genre  has_synopses  num words  \
# 0       0  November 2015          1               1             0          0
# 1       1  November 2014          1               1             1         44
# 2       1  November 2015          1               1             1        153
# 3       1  November 2014          1               1             1         59
# 4       0  November 2013          1               0             1        124
#
#    num uniques  num sentences  paragraphs  fk score  has excerpt  \
# 0            0              0           0      0.00            0
# 1           42              3           1     65.73            1
# 2          109              7           4     58.62            0
# 3           51              4           3     65.73            0
# 4           93              4           1     56.93            0
#
#    num words excerpt  num uniques excerpt  num sentences excerpt  \
# 0                  0                    0                      0
# 1                132                   96                     13
# 2                  0                    0                      0
# 3                  0                    0                      0
# 4                  0                    0                      0
#
#    paragraphs excerpt  fk score excerpt
# 0                   0              0.00
# 1                   7             78.25
# 2                   0              0.00
# 3                   0              0.00
# 4                   0              0.00

# %%
print "The fraction of winning novels is " + str(sum(novel_features['Winner'] / float(len(novel_features['Winner']))))
# Out:
# The fraction of winning novels is 0.6278850683

# %%
y = novel_features['Winner'].values
del novel_features['Winner']
del novel_features['Novel Date']

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from bokeh.plotting import figure,show,output_notebook
from bokeh.models import Range1d
output_notebook()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
def plot_roc_curve(target_test, target_predicted_proba):
    fpr, tpr, thresholds = roc_curve(target_test, target_predicted_proba[:, 1])
    
    roc_auc = auc(fpr, tpr)
    
    p = figure(title='Receiver Operating Characteristic')
    # Plot ROC curve
    p.line(x=fpr,y=tpr,legend='ROC curve (area = %0.3f)' % roc_auc)
    p.x_range=Range1d(0,1)
    p.y_range=Range1d(0,1)
    p.xaxis.axis_label='False Positive Rate or (1 - Specifity)'
    p.yaxis.axis_label='True Positive Rate or (Sensitivity)'
    p.legend.orientation = "bottom_right"
    show(p)
    
# %matplotlib inline

# %%
scaler = StandardScaler()
features_norm = scaler.fit_transform(novel_features)

trainX, testX, trainy, testy = train_test_split(features_norm, y, test_size=0.2, random_state=1)

# %%
model_lr = LogisticRegression(C=1)
print cross_val_score(model_lr,trainX,trainy,cv=10).mean()

model_lr.fit(trainX,trainy)
print pd.DataFrame(confusion_matrix(testy,model_lr.predict(testX)), index=['Predicted Class 0', 'Predicted Class 1'], 
                     columns=['Actual Class 0', 'Actual Class 1'])
print classification_report(testy,model_lr.predict(testX))
print model_lr.score(trainX,trainy)
plot_roc_curve(testy, model_lr.predict_proba(testX))
# Out:
# 0.62544114085
#                    Actual Class 0  Actual Class 1
# Predicted Class 0               1             158
# Predicted Class 1               0             266
#              precision    recall  f1-score   support
#
#           0       1.00      0.01      0.01       159
#           1       0.63      1.00      0.77       266
#
# avg / total       0.77      0.63      0.49       425
#
# 0.630153121319
# //anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="d146748b-e343-4e86-83fe-f1dd3f850ae0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d146748b-e343-4e86-83fe-f1dd3f850ae0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd146748b-e343-4e86-83fe-f1dd3f850ae0' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"645ad045-bf67-46e5-9218-4f5f7cfe3319": {"version": "0.11.0", "roots": {"root_ids": ["0eb7dc7b-e519-415d-9a22-164c086f45fd"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "WheelZoomTool", "id": "7242fabf-000e-48d8-8caf-ee05c85a42aa"}, {"attributes": {}, "type": "BasicTicker", "id": "2c663462-4024-49e7-bf80-0894c3e38fc7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "2a2794e5-4170-4dc0-a5b3-14a7181d0ef0"}, "ticker": {"type": "BasicTicker", "id": "2daf2458-f7fe-4e4f-95dd-d24174629acd"}}, "type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "9a6c9af0-7f14-4993-b270-76e09e405dda"}, "data_source": {"type": "ColumnDataSource", "id": "6227fd64-a36d-4e0f-891f-57711d57d5e0"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "68d34611-2d31-4c87-b926-c41e58849f16"}}, "type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}, {"attributes": {"x_range": {"type": "Range1d", "id": "3f9f9509-edc9-4f3b-9706-fb33f99fc960"}, "title": "Receiver Operating Characteristic", "y_range": {"type": "Range1d", "id": "640ccc7b-a4be-4a55-ae7f-f873cc1108ee"}, "renderers": [{"type": "LinearAxis", "id": "7c9ec64f-d2b2-4349-bbc7-0a3c36aa17fd"}, {"type": "Grid", "id": "f116403c-d814-487b-ba5e-fa4fd351c5da"}, {"type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}, {"type": "Grid", "id": "e74a2a72-4d52-412d-879a-457c615f464e"}, {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}, {"type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}], "below": [{"type": "LinearAxis", "id": "7c9ec64f-d2b2-4349-bbc7-0a3c36aa17fd"}], "tool_events": {"type": "ToolEvents", "id": "f4c89d2c-b202-4169-a77b-7e338a25a55a"}, "tools": [{"type": "PanTool", "id": "a32ee353-b6f4-4922-a4e4-e6819f7c963b"}, {"type": "WheelZoomTool", "id": "7242fabf-000e-48d8-8caf-ee05c85a42aa"}, {"type": "BoxZoomTool", "id": "2db97819-cd3c-4728-8586-89385dd93559"}, {"type": "PreviewSaveTool", "id": "cd3cda15-ee79-4062-8ccd-3020cb6ee326"}, {"type": "ResizeTool", "id": "b7d05aa1-b330-4335-a12f-e2f1f006fbb7"}, {"type": "ResetTool", "id": "f5c414db-9636-437c-8a68-98512fbe1e25"}, {"type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}], "left": [{"type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}]}, "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd", "subtype": "Figure"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "overlay": {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}}, "type": "BoxZoomTool", "id": "2db97819-cd3c-4728-8586-89385dd93559"}, {"attributes": {}, "type": "ToolEvents", "id": "f4c89d2c-b202-4169-a77b-7e338a25a55a"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "9a6c9af0-7f14-4993-b270-76e09e405dda"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "legends": [["ROC curve (area = 0.547)", [{"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}]]], "location": "bottom_right"}, "type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "PreviewSaveTool", "id": "cd3cda15-ee79-4062-8ccd-3020cb6ee326"},  ...

# %% [markdown]
# The Logistic Regression didn't do too well.  Let's try applying PCA before running the Logistic Regression again.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
pca_features = pca.fit(features_norm).transform(features_norm)

# %%
pca_trainX, pca_testX, pca_trainy, pca_testy = train_test_split(pca_features, y, test_size=0.2, random_state=1)

# %%
new_model_lr = LogisticRegression(C=1)

print cross_val_score(model_lr,pca_trainX,pca_trainy,cv=10).mean()

new_model_lr.fit(pca_trainX,pca_trainy)
print pd.DataFrame(confusion_matrix(pca_testy,new_model_lr.predict(pca_testX)), index=['Predicted Class 0', 'Predicted Class 1'], 
                     columns=['Actual Class 0', 'Actual Class 1'])
print classification_report(pca_testy,new_model_lr.predict(pca_testX))
print new_model_lr.score(pca_trainX,pca_trainy)
plot_roc_curve(pca_testy, new_model_lr.predict_proba(pca_testX))
# Out:
# 0.62544114085
#                    Actual Class 0  Actual Class 1
# Predicted Class 0               1             158
# Predicted Class 1               0             266
#              precision    recall  f1-score   support
#
#           0       1.00      0.01      0.01       159
#           1       0.63      1.00      0.77       266
#
# avg / total       0.77      0.63      0.49       425
#
# 0.630153121319
# //anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="45adc2e5-947c-48b6-a78a-1eced7cadb63"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("45adc2e5-947c-48b6-a78a-1eced7cadb63");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '45adc2e5-947c-48b6-a78a-1eced7cadb63' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b99904fc-70b5-4685-b120-b55c8accc9e6": {"version": "0.11.0", "roots": {"root_ids": ["0eb7dc7b-e519-415d-9a22-164c086f45fd", "e6ea7cae-c5b4-441f-b65a-afb49a246d75"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "WheelZoomTool", "id": "7242fabf-000e-48d8-8caf-ee05c85a42aa"}, {"attributes": {}, "type": "BasicTicker", "id": "df5426e2-2482-4102-a042-5472e87effc5"}, {"attributes": {}, "type": "BasicTicker", "id": "2c663462-4024-49e7-bf80-0894c3e38fc7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "2a2794e5-4170-4dc0-a5b3-14a7181d0ef0"}, "ticker": {"type": "BasicTicker", "id": "2daf2458-f7fe-4e4f-95dd-d24174629acd"}}, "type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e6ea7cae-c5b4-441f-b65a-afb49a246d75"}, "legends": [["ROC curve (area = 0.547)", [{"type": "GlyphRenderer", "id": "b99fb454-3d2a-464f-88cf-cea1983cb3ec"}]]], "location": "bottom_right"}, "type": "Legend", "id": "6c0703d3-55da-4c56-a8dd-0aa35b86af93"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "9a6c9af0-7f14-4993-b270-76e09e405dda"}, "data_source": {"type": "ColumnDataSource", "id": "6227fd64-a36d-4e0f-891f-57711d57d5e0"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "68d34611-2d31-4c87-b926-c41e58849f16"}}, "type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}, {"attributes": {"x_range": {"type": "Range1d", "id": "3f9f9509-edc9-4f3b-9706-fb33f99fc960"}, "title": "Receiver Operating Characteristic", "y_range": {"type": "Range1d", "id": "640ccc7b-a4be-4a55-ae7f-f873cc1108ee"}, "renderers": [{"type": "LinearAxis", "id": "7c9ec64f-d2b2-4349-bbc7-0a3c36aa17fd"}, {"type": "Grid", "id": "f116403c-d814-487b-ba5e-fa4fd351c5da"}, {"type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}, {"type": "Grid", "id": "e74a2a72-4d52-412d-879a-457c615f464e"}, {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}, {"type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}], "below": [{"type": "LinearAxis", "id": "7c9ec64f-d2b2-4349-bbc7-0a3c36aa17fd"}], "tool_events": {"type": "ToolEvents", "id": "f4c89d2c-b202-4169-a77b-7e338a25a55a"}, "tools": [{"type": "PanTool", "id": "a32ee353-b6f4-4922-a4e4-e6819f7c963b"}, {"type": "WheelZoomTool", "id": "7242fabf-000e-48d8-8caf-ee05c85a42aa"}, {"type": "BoxZoomTool", "id": "2db97819-cd3c-4728-8586-89385dd93559"}, {"type": "PreviewSaveTool", "id": "cd3cda15-ee79-4062-8ccd-3020cb6ee326"}, {"type": "ResizeTool", "id": "b7d05aa1-b330-4335-a12f-e2f1f006fbb7"}, {"type": "ResetTool", "id": "f5c414db-9636-437c-8a68-98512fbe1e25"}, {"type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}], "left": [{"type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}]}, "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd", "subtype": "Figure"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "f461c59a-41fb-4470-ae5e-86d9015f93bd"}, "data_source": {"type": "ColumnDataSource", "id": "6632f585-2de7-4d56-bd66-14709b26119b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "21a0614b-54a7-4201-bf5d-60d2ac1e77a0"}}, "type": "GlyphRenderer", "id": "b99fb454-3d2a-464f-88cf-cea1983cb3ec"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "overlay": {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}}, "type": "BoxZoom ...

# %% [markdown]
# Let's run other models to see if they do any better.
#
# ### K Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(4)

print cross_val_score(model_knn,pca_trainX,pca_trainy,cv=10).mean()

model_knn.fit(pca_trainX,pca_trainy)
print pd.DataFrame(confusion_matrix(pca_testy,model_knn.predict(pca_testX)), index=['Predicted Class 0', 'Predicted Class 1'], 
                     columns=['Actual Class 0', 'Actual Class 1'])
print classification_report(pca_testy,model_knn.predict(pca_testX))
print model_knn.score(pca_trainX,pca_trainy)
plot_roc_curve(pca_testy, model_knn.predict_proba(pca_testX))
# Out:
# 0.530626868831
#                    Actual Class 0  Actual Class 1
# Predicted Class 0              52             107
# Predicted Class 1              81             185
#              precision    recall  f1-score   support
#
#           0       0.39      0.33      0.36       159
#           1       0.63      0.70      0.66       266
#
# avg / total       0.54      0.56      0.55       425
#
# 0.679623085984
# //anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="c47a3dc3-85d8-4a3e-9b4a-53fe7ff4c91e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c47a3dc3-85d8-4a3e-9b4a-53fe7ff4c91e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c47a3dc3-85d8-4a3e-9b4a-53fe7ff4c91e' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3ca6ccc3-0eb2-4fb5-a709-9d9c6971d678": {"version": "0.11.0", "roots": {"root_ids": ["0eb7dc7b-e519-415d-9a22-164c086f45fd", "e6ea7cae-c5b4-441f-b65a-afb49a246d75", "18ca2071-8b19-48f5-8d67-9748699c6e3b"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "WheelZoomTool", "id": "7242fabf-000e-48d8-8caf-ee05c85a42aa"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "10ef035c-85db-40f0-8af0-bd798d462aa4"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [0.0, 0.16165413533834586, 0.6954887218045113, 0.8721804511278195, 0.981203007518797, 1.0], "x": [0.0, 0.1069182389937107, 0.6729559748427673, 0.9308176100628931, 0.9874213836477987, 1.0]}}, "type": "ColumnDataSource", "id": "ffe44274-0e8e-4010-8f70-2d299934b829"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "0f89ba07-cf6a-438c-9233-56baa3ad9071"}, {"attributes": {}, "type": "BasicTicker", "id": "df5426e2-2482-4102-a042-5472e87effc5"}, {"attributes": {}, "type": "BasicTicker", "id": "2c663462-4024-49e7-bf80-0894c3e38fc7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "2a2794e5-4170-4dc0-a5b3-14a7181d0ef0"}, "ticker": {"type": "BasicTicker", "id": "2daf2458-f7fe-4e4f-95dd-d24174629acd"}}, "type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e6ea7cae-c5b4-441f-b65a-afb49a246d75"}, "legends": [["ROC curve (area = 0.547)", [{"type": "GlyphRenderer", "id": "b99fb454-3d2a-464f-88cf-cea1983cb3ec"}]]], "location": "bottom_right"}, "type": "Legend", "id": "6c0703d3-55da-4c56-a8dd-0aa35b86af93"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "18ca2071-8b19-48f5-8d67-9748699c6e3b"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "aea2ba9f-e86f-441c-8544-a819e8cddeb5"}, "ticker": {"type": "BasicTicker", "id": "573e930c-6819-472e-9a30-cb4f6e4f1233"}}, "type": "LinearAxis", "id": "9d34c49e-2935-4d3f-ab2f-57b3157b739d"}, {"attributes": {}, "type": "BasicTicker", "id": "6f3924b6-1740-49d1-b8b5-883f6831507a"}, {"attributes": {"x_range": {"type": "Range1d", "id": "3f9f9509-edc9-4f3b-9706-fb33f99fc960"}, "title": "Receiver Operating Characteristic", "y_range": {"type": "Range1d", "id": "640ccc7b-a4be-4a55-ae7f-f873cc1108ee"}, "renderers": [{"type": "LinearAxis", "id": "7c9ec64f-d2b2-4349-bbc7-0a3c36aa17fd"}, {"type": "Grid", "id": "f116403c-d814-487b-ba5e-fa4fd351c5da"}, {"type": "LinearAxis", "id": "5ac13b2c-1cd8-4825-83cf-263cc2a49fd9"}, {"type": "Grid", "id": "e74a2a72-4d52-412d-879a-457c615f464e"}, {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}, {"type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}], "below": [{"type": "LinearAxis", "id": "7c9ec64f-d2b2-4349-bbc7-0a3c36aa17fd"}], "tool_events": {"type": "ToolEvents", "id": "f4c89d2c-b202-4169-a77b-7e338a25a55a"}, "tools": [{"type": "PanTool", "id": "a32ee353-b6f4-4922-a4e4-e6819f7c963b"}, {"type": "WheelZoomTool", "id": "7242fabf-000e-48d8-8caf-ee05c85a42aa"}, {"type": "Bo ...

# %% [markdown]
# Unurprisingly, K Neighbors performs worse than Logistic Regression.

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_nb = GaussianNB()
print cross_val_score(model_nb,pca_trainX,pca_trainy,cv=10).mean()

model_nb.fit(pca_trainX,pca_trainy)
print pd.DataFrame(confusion_matrix(testy,model_nb.predict(pca_testX)), index=['Predicted Class 0', 'Predicted Class 1'], 
                     columns=['Actual Class 0', 'Actual Class 1'])
print classification_report(pca_testy,model_nb.predict(pca_testX))
print model_nb.score(pca_trainX,pca_trainy)
plot_roc_curve(pca_testy, model_nb.predict_proba(pca_testX))
# Out:
# 0.544747630185
#                    Actual Class 0  Actual Class 1
# Predicted Class 0              37             122
# Predicted Class 1              67             199
#              precision    recall  f1-score   support
#
#           0       0.36      0.23      0.28       159
#           1       0.62      0.75      0.68       266
#
# avg / total       0.52      0.56      0.53       425
#
# 0.587750294464
# //anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="2c05f1a4-9b97-48a8-b45f-763e857d1cd9"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2c05f1a4-9b97-48a8-b45f-763e857d1cd9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2c05f1a4-9b97-48a8-b45f-763e857d1cd9' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"647e1615-7180-4628-b732-c737d706955d": {"version": "0.11.0", "roots": {"root_ids": ["0eb7dc7b-e519-415d-9a22-164c086f45fd", "e6ea7cae-c5b4-441f-b65a-afb49a246d75", "18ca2071-8b19-48f5-8d67-9748699c6e3b", "8ee9b154-de0e-424e-aa3f-3414316d127d"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "3ed9acb0-cf97-4360-a88f-5964fac3f4e4"}, "ticker": {"type": "BasicTicker", "id": "ad7c6c07-45bf-42aa-8712-4369cdf49398"}}, "type": "LinearAxis", "id": "60b86680-acf6-474c-b3f3-d9978ba8a51e"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "3a84a7ad-8b92-4cdb-a806-e1a9a2822923"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "False Positive Rate or (1 - Specifity)", "formatter": {"type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, "ticker": {"type": "BasicTicker", "id": "5e4f43e6-b99f-43a1-872c-fcd44df370dc"}}, "type": "LinearAxis", "id": "35f76e53-87d6-46a0-bd31-5853d2ecffc9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "18ca2071-8b19-48f5-8d67-9748699c6e3b"}}, "type": "ResetTool", "id": "b187a7dd-1bdf-4f04-8257-041f8b253732"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "overlay": {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}}, "type": "BoxZoomTool", "id": "2db97819-cd3c-4728-8586-89385dd93559"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "legends": [["ROC curve (area = 0.547)", [{"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}]]], "location": "bottom_right"}, "type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"attributes": {"callback": null}, "type": "Range1d", "id": "d431e251-a2fa-460c-9a8e-ed373332cf8f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "PreviewSaveTool", "id": "cd3cda15-ee79-4062-8ccd-3020cb6ee326"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, {"attributes": {}, "type": "BasicTicker", "id": "13ba643e-353d-4ca4-b0a4-91873326fb08"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e6ea7cae-c5b4-441f-b65a-afb49a246d75"}}, "type": "ResizeTool", "id": "c1acf624-4066-4121-a105-424c6bb4f4d7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "ticker": {"type": "BasicTicker", "id": "2c663462-4024-49e7-bf80-0894c3e38fc7"}}, "type": "Grid", "id": "f116403c-d814-487b-ba5e-fa4fd351c5da"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}}, "type": "ResizeTool", "id": "7c505337-c2a8-4a23-b58b-67efae77aa89"}, {"attributes": {"callback": null}, "type": "Range1d", "id": "acb40ab4-947f-4798-8b57-6b9181acb5df"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "ticker": {"type": "BasicTicker", "id": "2daf2458-f7fe-4e4f-95dd-d24174629acd"}, "dimension": 1}, "type": "Grid", "id": "e74a2a72-4d52-412d-879a-457c615f464e"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-29 ...

# %% [markdown]
# Also surprising, Naive Bayes doesn't as well as Logistic Regression in this case.

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier(max_depth=3, random_state=1)
print cross_val_score(model_dt,pca_trainX,pca_trainy,cv=10).mean()

model_dt.fit(pca_trainX,pca_trainy)
print pd.DataFrame(confusion_matrix(pca_testy,model_dt.predict(pca_testX)), index=['Predicted Class 0', 'Predicted Class 1'], 
                     columns=['Actual Class 0', 'Actual Class 1'])
print classification_report(pca_testy,model_dt.predict(pca_testX))
print model_dt.score(pca_trainX,pca_trainy)
plot_roc_curve(pca_testy, model_dt.predict_proba(pca_testX))
# Out:
# 0.607790438505
#                    Actual Class 0  Actual Class 1
# Predicted Class 0               2             157
# Predicted Class 1               2             264
#              precision    recall  f1-score   support
#
#           0       0.50      0.01      0.02       159
#           1       0.63      0.99      0.77       266
#
# avg / total       0.58      0.63      0.49       425
#
# 0.633097762073
# //anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="22b4dfec-dc21-4652-83d2-028a2f54bb43"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("22b4dfec-dc21-4652-83d2-028a2f54bb43");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '22b4dfec-dc21-4652-83d2-028a2f54bb43' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e10241ca-397c-477c-b812-2ee3990cb15e": {"version": "0.11.0", "roots": {"root_ids": ["0eb7dc7b-e519-415d-9a22-164c086f45fd", "e6ea7cae-c5b4-441f-b65a-afb49a246d75", "18ca2071-8b19-48f5-8d67-9748699c6e3b", "8ee9b154-de0e-424e-aa3f-3414316d127d", "a931bd0c-0f21-4da4-b235-6fc46cad8eb4"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "3a84a7ad-8b92-4cdb-a806-e1a9a2822923"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "False Positive Rate or (1 - Specifity)", "formatter": {"type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, "ticker": {"type": "BasicTicker", "id": "5e4f43e6-b99f-43a1-872c-fcd44df370dc"}}, "type": "LinearAxis", "id": "35f76e53-87d6-46a0-bd31-5853d2ecffc9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "18ca2071-8b19-48f5-8d67-9748699c6e3b"}}, "type": "ResetTool", "id": "b187a7dd-1bdf-4f04-8257-041f8b253732"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "overlay": {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}}, "type": "BoxZoomTool", "id": "2db97819-cd3c-4728-8586-89385dd93559"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "legends": [["ROC curve (area = 0.547)", [{"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}]]], "location": "bottom_right"}, "type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"attributes": {"callback": null}, "type": "Range1d", "id": "d431e251-a2fa-460c-9a8e-ed373332cf8f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "PreviewSaveTool", "id": "cd3cda15-ee79-4062-8ccd-3020cb6ee326"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "3ed9acb0-cf97-4360-a88f-5964fac3f4e4"}, "ticker": {"type": "BasicTicker", "id": "ad7c6c07-45bf-42aa-8712-4369cdf49398"}}, "type": "LinearAxis", "id": "60b86680-acf6-474c-b3f3-d9978ba8a51e"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [0.0, 0.011278195488721804, 0.11278195488721804, 0.15037593984962405, 0.24436090225563908, 0.47368421052631576, 0.9849624060150376, 0.9924812030075187, 1.0], "x": [0.0, 0.006289308176100629, 0.07547169811320754, 0.11320754716981132, 0.2138364779874214, 0.44654088050314467, 0.9874213836477987, 0.9874213836477987, 1.0]}}, "type": "ColumnDataSource", "id": "ffe4068d-387f-4715-ab85-f675d63d8218"}, {"attributes": {}, "type": "BasicTicker", "id": "13ba643e-353d-4ca4-b0a4-91873326fb08"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e6ea7cae-c5b4-441f-b65a-afb49a246d75"}}, "type": "ResizeTool", "id": "c1acf624-4066-4121-a105-424c6bb4f4d7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "ticker": {"type": "BasicTicker", "id": "2c663462-4024-49e7-bf80-0894c3e38fc7"}}, "type": "Grid", "id": "f116403c-d814-487b-ba5e-fa4fd351c5da"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a931bd0c-0f21-4da4-b235-6fc46cad8eb4"}}, "type": "PanTool", "id": "b180d8bb-68d4-4191-a5e1-6672e10f51cd"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}}, "type": "ResizeTool", "id": "7c505337-c2a8-4a23-b58b-67efae77aa89"}, {"attributes": {"callback": null}, "type": "Range1d", "id": "acb40ab4-947f-4798-8b57-6b9181a ...

# %% [markdown]
# This Decision Tree does only slightly better compared to the others, but still not an optimal score.

# %%
dt_importances = pd.DataFrame(zip(novel_features.columns, model_dt.feature_importances_))
dt_importances.sort_values(1, ascending=False).head() # most to least predictive
# Out:
#                         0         1
# 0               has genre  0.261460
# 7                fk score  0.189264
# 11  num sentences excerpt  0.130252
# 8             has excerpt  0.127461
# 9       num words excerpt  0.106410

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(max_depth=3, n_estimators=100)
print cross_val_score(model_rf,pca_trainX,pca_trainy,cv=10).mean()

model_rf.fit(pca_trainX,pca_trainy)
print pd.DataFrame(confusion_matrix(pca_testy,model_dt.predict(pca_testX)), index=['Predicted Class 0', 'Predicted Class 1'], 
                     columns=['Actual Class 0', 'Actual Class 1'])
print classification_report(pca_testy,model_rf.predict(pca_testX))
print model_rf.score(pca_trainX,pca_trainy)
plot_roc_curve(pca_testy, model_rf.predict_proba(pca_testX))
# Out:
# 0.628385838712
#                    Actual Class 0  Actual Class 1
# Predicted Class 0               2             157
# Predicted Class 1               2             264
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       159
#           1       0.63      1.00      0.77       266
#
# avg / total       0.39      0.63      0.48       425
#
# 0.629564193168
# //anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="04c6b0fd-d4c2-4d84-a93e-900e7f44130f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("04c6b0fd-d4c2-4d84-a93e-900e7f44130f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '04c6b0fd-d4c2-4d84-a93e-900e7f44130f' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"58b74fcc-318f-4ee7-9e87-52fe7d7fe9a4": {"version": "0.11.0", "roots": {"root_ids": ["0eb7dc7b-e519-415d-9a22-164c086f45fd", "e6ea7cae-c5b4-441f-b65a-afb49a246d75", "18ca2071-8b19-48f5-8d67-9748699c6e3b", "8ee9b154-de0e-424e-aa3f-3414316d127d", "a931bd0c-0f21-4da4-b235-6fc46cad8eb4", "a832fd1c-4566-4041-a2ba-2a37759016f5"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "3a84a7ad-8b92-4cdb-a806-e1a9a2822923"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "False Positive Rate or (1 - Specifity)", "formatter": {"type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, "ticker": {"type": "BasicTicker", "id": "5e4f43e6-b99f-43a1-872c-fcd44df370dc"}}, "type": "LinearAxis", "id": "35f76e53-87d6-46a0-bd31-5853d2ecffc9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "18ca2071-8b19-48f5-8d67-9748699c6e3b"}}, "type": "ResetTool", "id": "b187a7dd-1bdf-4f04-8257-041f8b253732"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "overlay": {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}}, "type": "BoxZoomTool", "id": "2db97819-cd3c-4728-8586-89385dd93559"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "10ef035c-85db-40f0-8af0-bd798d462aa4"}, "data_source": {"type": "ColumnDataSource", "id": "ffe44274-0e8e-4010-8f70-2d299934b829"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "3090bf6b-4616-4c7f-9d7c-518e6d7a6345"}}, "type": "GlyphRenderer", "id": "64ee7711-61a4-41c7-b142-ce24d12fb3c2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "legends": [["ROC curve (area = 0.547)", [{"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}]]], "location": "bottom_right"}, "type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"attributes": {"callback": null}, "type": "Range1d", "id": "d431e251-a2fa-460c-9a8e-ed373332cf8f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "PreviewSaveTool", "id": "cd3cda15-ee79-4062-8ccd-3020cb6ee326"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "3ed9acb0-cf97-4360-a88f-5964fac3f4e4"}, "ticker": {"type": "BasicTicker", "id": "ad7c6c07-45bf-42aa-8712-4369cdf49398"}}, "type": "LinearAxis", "id": "60b86680-acf6-474c-b3f3-d9978ba8a51e"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [0.0, 0.011278195488721804, 0.11278195488721804, 0.15037593984962405, 0.24436090225563908, 0.47368421052631576, 0.9849624060150376, 0.9924812030075187, 1.0], "x": [0.0, 0.006289308176100629, 0.07547169811320754, 0.11320754716981132, 0.2138364779874214, 0.44654088050314467, 0.9874213836477987, 0.9874213836477987, 1.0]}}, "type": "ColumnDataSource", "id": "ffe4068d-387f-4715-ab85-f675d63d8218"}, {"attributes": {"callback": null}, "type": "Range1d", "id": "6596cac3-d307-4762-bf89-d4106b0a59a8"}, {"attributes": {}, "type": "BasicTicker", "id": "13ba643e-353d-4ca4-b0a4-91873326fb08"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e6ea7cae-c5b4-441f-b65a-afb49a246d75"}}, "type": "ResizeTool", "id": "c1acf624-4066-4121-a105-424c6bb4f4d7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "ticker": {"type": "BasicTicker", "id": "2c663462-4024-49e7-bf80-0 ...

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
model_svc = SVC(kernel="linear",C=1)
print cross_val_score(model_rf,pca_trainX,pca_trainy,cv=10).mean()

model_rf.fit(pca_trainX,pca_trainy)
print pd.DataFrame(confusion_matrix(pca_testy,model_dt.predict(pca_testX)), index=['Predicted Class 0', 'Predicted Class 1'], 
                     columns=['Actual Class 0', 'Actual Class 1'])
print classification_report(pca_testy,model_rf.predict(pca_testX))
print model_rf.score(pca_trainX,pca_trainy)
plot_roc_curve(pca_testy, model_rf.predict_proba(pca_testX))
# Out:
# 0.628385838712
#                    Actual Class 0  Actual Class 1
# Predicted Class 0               2             157
# Predicted Class 1               2             264
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       159
#           1       0.63      1.00      0.77       266
#
# avg / total       0.39      0.63      0.48       425
#
# 0.628975265018
# //anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="51f90ebc-3384-439c-98e5-3eecf1d847af"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51f90ebc-3384-439c-98e5-3eecf1d847af");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51f90ebc-3384-439c-98e5-3eecf1d847af' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2da5cf73-2cc4-41e4-8b9c-282825f7f874": {"version": "0.11.0", "roots": {"root_ids": ["0eb7dc7b-e519-415d-9a22-164c086f45fd", "e6ea7cae-c5b4-441f-b65a-afb49a246d75", "18ca2071-8b19-48f5-8d67-9748699c6e3b", "8ee9b154-de0e-424e-aa3f-3414316d127d", "a931bd0c-0f21-4da4-b235-6fc46cad8eb4", "a832fd1c-4566-4041-a2ba-2a37759016f5", "d1daf238-85a1-4160-ac7a-cebddf44d988"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "HelpTool", "id": "cf734180-800a-4959-8588-f1e0940451d2"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d1daf238-85a1-4160-ac7a-cebddf44d988"}, "ticker": {"type": "BasicTicker", "id": "38d78407-9cb2-4a24-b803-34f736f99547"}, "dimension": 1}, "type": "Grid", "id": "e26a26b8-c244-48f8-a058-a244147939c3"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d1daf238-85a1-4160-ac7a-cebddf44d988"}}, "type": "PanTool", "id": "94e592f2-6075-4a9b-90a7-39fd8789046a"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d1daf238-85a1-4160-ac7a-cebddf44d988"}, "legends": [["ROC curve (area = 0.513)", [{"type": "GlyphRenderer", "id": "322f0e6d-b50a-4762-832e-e015dce4c387"}]]], "location": "bottom_right"}, "type": "Legend", "id": "bc22721f-4937-4ef7-b561-5e2140884902"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "3a84a7ad-8b92-4cdb-a806-e1a9a2822923"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "False Positive Rate or (1 - Specifity)", "formatter": {"type": "BasicTickFormatter", "id": "51a29910-f63f-4808-bcb9-e05f00c3ff4a"}, "ticker": {"type": "BasicTicker", "id": "5e4f43e6-b99f-43a1-872c-fcd44df370dc"}}, "type": "LinearAxis", "id": "35f76e53-87d6-46a0-bd31-5853d2ecffc9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "18ca2071-8b19-48f5-8d67-9748699c6e3b"}}, "type": "ResetTool", "id": "b187a7dd-1bdf-4f04-8257-041f8b253732"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "overlay": {"type": "BoxAnnotation", "id": "54c59000-cbff-4ad5-be18-295162d13d9f"}}, "type": "BoxZoomTool", "id": "2db97819-cd3c-4728-8586-89385dd93559"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}, "legends": [["ROC curve (area = 0.547)", [{"type": "GlyphRenderer", "id": "52a2d646-0368-4b15-bf96-fc408f6fafae"}]]], "location": "bottom_right"}, "type": "Legend", "id": "8a568c95-47b8-4d97-9e58-042820f22a6c"}, {"attributes": {"callback": null}, "type": "Range1d", "id": "d431e251-a2fa-460c-9a8e-ed373332cf8f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0eb7dc7b-e519-415d-9a22-164c086f45fd"}}, "type": "PreviewSaveTool", "id": "cd3cda15-ee79-4062-8ccd-3020cb6ee326"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "8ee9b154-de0e-424e-aa3f-3414316d127d"}, "axis_label": "True Positive Rate or (Sensitivity)", "formatter": {"type": "BasicTickFormatter", "id": "3ed9acb0-cf97-4360-a88f-5964fac3f4e4"}, "ticker": {"type": "BasicTicker", "id": "ad7c6c07-45bf-42aa-8712-4369cdf49398"}}, "type": "LinearAxis", "id": "60b86680-acf6-474c-b3f3-d9978ba8a51e"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [0.0, 0.011278195488721804, 0.11278195488721804, 0.15037593984962405, 0.24436090225563908, 0.47368421052631576, 0.9849624060150376, 0.9924812030075187, 1.0], "x": [0.0, 0.006289308176100629, 0.07547169811320754, 0.11320754716981132, 0.2138364779874214, 0.44654088050314467, 0.9874213836477987, 0.9874213836477987, 1.0]}}, "type": "ColumnDataSource", "id": "ffe4068d-387f-4715-ab85-f675d63d8218"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d1daf238-85a1-4160-ac7a-cebddf44d988"}, "ticker": {"t ...

# %% [markdown]
# So Decision Trees and Support Vector Machines don't perform much better than guessing either.
# Maybe it just doesn't make sense to predict if a novel wins just based on it's synopses or excerpt.  Don't judge a book by it's cover I guess.
