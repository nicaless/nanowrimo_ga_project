# %%
import pandas as pd

# %%
# get the raw basic info data 
df = pd.read_csv("../rawdata/user_profiles_basicinfo.csv")

# %%
df = df[['Writer Name', 'Member Length', 'LifetimeWordCount', 'url']]
df
# Out:
#                     Writer Name              Member Length LifetimeWordCount  \
# 0                      Nicaless   Member for about 2 years            75,148
# 1               Rachel B. Moore  Member for about 10 years           528,693
# 2                  abookishbabe   Member for about 1 month            29,299
# 3                    alexabexis  Member for about 11 years           554,300
# 4              AllYellowFlowers   Member for about 3 years            41,428
# 5                     animalrza   Member for about 3 years            88,131
# 6                      Cafenuit   Member for about 3 years            50,145
# 7                      Carmelon   Member for about 1 month            18,999
# 8                        carozy    Member for over 4 years            38,981
# 9                       chrisk0  Member for about 10 years           313,332
# 10      ComeOnAndWriteThisNovel   Member for about 3 years            11,055
# ...

# %%
# parses the string in Member Length column
def getMemberLength(string):
    string = string.split("Member for ")[1]
    string = string.split(" ")
    # if writer has been a member for less than a year, length of the string will be 2 instead of 3
    if len(string) < 3:
        # convert months into years
        memberlength = int(string[0]) * (1.0/12.0)
    else:
        memberlength = int(string[1])
    return memberlength

getMemberLength(df['Member Length'][0])
# Out:
# 2

# %%
df['Member Length'] = df['Member Length'].apply(lambda x: getMemberLength(x))
df.head()
# Out:
#         Writer Name  Member Length LifetimeWordCount  \
# 0          Nicaless              2            75,148
# 1   Rachel B. Moore             10           528,693
# 2      abookishbabe              1            29,299
# 3        alexabexis             11           554,300
# 4  AllYellowFlowers              3            41,428
#
#                                                  url
# 0         http://nanowrimo.org/participants/nicaless
# 1   http://nanowrimo.org/participants/rachel-b-moore
# 2     http://nanowrimo.org/participants/abookishbabe
# 3       http://nanowrimo.org/participants/alexabexis
# 4  http://nanowrimo.org/participants/AllYellowFlo...

# %%
facts = pd.read_csv("../clean data/fact_sheet_parsed.csv")

# %%
facts = facts[['Age', 'Birthday', 'Favorite books or authors', 'Favorite noveling music', 'Hobbies', 'Location', 'Occupation', 'Primary Role', 'Sponsorship URL']]

# %%
# concatenate the facts data frame with the basic info dataframe
pd.concat([df, facts], axis = 1)
# Out:
#                     Writer Name  Member Length LifetimeWordCount  \
# 0                      Nicaless       2.000000            75,148
# 1               Rachel B. Moore      10.000000           528,693
# 2                  abookishbabe       1.000000            29,299
# 3                    alexabexis      11.000000           554,300
# 4              AllYellowFlowers       3.000000            41,428
# 5                     animalrza       3.000000            88,131
# 6                      Cafenuit       3.000000            50,145
# 7                      Carmelon       1.000000            18,999
# 8                        carozy       4.000000            38,981
# 9                       chrisk0      10.000000           313,332
# 10      ComeOnAndWriteThisNovel       3.000000            11,055
# 11                       cretsi       5.000000           310,993
# 12                       dazart       1.000000             3,483
# ...

# %%
summary = pd.concat([df, facts], axis = 1)

# %%
summary.to_csv('../clean data/user_summary.csv')
